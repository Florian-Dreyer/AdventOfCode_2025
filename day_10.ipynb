# %% [markdown]
# # Solution for Puzzle x

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import pulp
import os
from typing import List, Union
from tqdm import tqdm

# %% [markdown]
# ## Input Data

# %%
def read_and_parse_irregular_data(file_path: str) -> pd.DataFrame:
    """
    Reads an irregularly formatted text file line by line, parses the data 
    blocks using string splitting, and returns a consolidated Pandas DataFrame.

    Args:
        file_path: The path to the input file (e.g., 'input/test.csv').

    Returns:
        A pandas DataFrame containing the parsed data.
    """
    if not os.path.exists(file_path):
        raise ValueError(f"Error: File not found at '{file_path}'. Please check the path.")
        
    raw_lines = []
    try:
        # Read the entire file content into a list of strings
        with open(file_path, 'r', encoding='utf-8') as file:
            # Strip whitespace and filter out empty lines
            raw_lines = [line.strip() for line in file if line.strip()]
    except Exception as e:
        raise RuntimeError(f"An error occurred while reading the file: {e}")

    parsed_data = []

    # Parse each line string
    for line in raw_lines:

        # Split the line by spaces to separate the data blocks
        parts = line.split()
        
        # Check if the line contains enough data blocks
        if len(parts) < 3:
            print(f"Skipping line due to insufficient data: {line}")
            continue

        light_diagram = parts[0]
        joltage_requirements = parts[-1]
        buttons = parts[1:-1]
        
        # Prepare the data dictionary for the row
        row_dict = {'light_diagram': light_diagram, 'joltage_requirements': joltage_requirements, 'buttons': buttons}
        
        parsed_data.append(row_dict)

    # 3. Create the final DataFrame from the list of dictionaries
    df = pd.DataFrame(parsed_data)
    
    return df

file_to_process = 'input/day_10.csv'
input = read_and_parse_irregular_data(file_to_process)

print("\n--- Resulting DataFrame ---")
print(input.head(5))
# Out:
# --- Resulting DataFrame ---
#   light_diagram    joltage_requirements  \
# 0      [#...##]  {132,30,23,13,121,115}
# 1        [##.#]            {2,18,18,20}
# 2      [.##...]     {38,30,29,22,13,25}
# 3      [#..###]      {22,51,19,63,22,1}
# 4      [#.#.##]     {13,43,33,29,40,41}
#
#                                              buttons
# 0         [(0,1,3,4,5), (0,4,5), (1,2,3,4), (0,1,2)]
# 1                                [(0,3), (1), (2,3)]
# 2    [(0,1,5), (0,2,3,5), (0,3,4), (1,2), (0,1,2,4)]
# 3  [(0,5), (1,3), (1,3,4), (0,1,2,3), (3), (0,1,3...
# 4  [(2,3,4,5), (0,2,4,5), (0,1,4), (1,5), (1,2,3,...

# %% [markdown]
# ## Part One

# %%
def apply_button(status, button):
    """Applies button on all lamps in status."""
    button = button[1:-1] #strip ()
    lamps = button.split(",")
    for lamp in lamps:
        status[int(lamp)] *= -1
    return status

def bfs(curr_status, goal_status, buttons):
    """Performs BFS where buttons are vertices and lamp status lists the nodes."""
    seen = set()
    stack = [(curr_status, 0)]
    while stack:
        curr, curr_count = stack.pop(0)
        if curr == goal_status:
            return curr_count
        for button in buttons:
            new_status = apply_button(curr.copy(), button)
            if tuple(new_status) not in seen:
                seen.add(tuple(new_status))
                stack.append((new_status, curr_count+1))
    return -1

number_buttons_pressed = []
for idx, row in tqdm(input.iterrows(), total=len(input)):
    status_lights = [-1 for _ in range(len(row["light_diagram"])-2)]
    status_lights_goal = [-1 if status == "." else 1 for status in row["light_diagram"][1:-1]]
    buttons = row["buttons"]
    number_buttons_pressed_row = bfs(status_lights, status_lights_goal, buttons)
    number_buttons_pressed.append(number_buttons_pressed_row)
print(f"The fewest button presses required are {sum(number_buttons_pressed)}")
# Out:
# 100%|██████████| 187/187 [00:00<00:00, 1498.50it/s]
# The fewest button presses required are 491

# %% [markdown]
# ## Part Two

# %%
# Too slow because the state space explodes

def apply_button(status, button):
    """Applies button on all lamps in status."""
    button = button[1:-1] #strip ()
    levers = button.split(",")
    for lever in levers:
        status[int(lever)] += 1
    return status

def bfs(curr_status, goal_status, buttons):
    """Performs BFS where buttons are vertices and joltage levels the nodes."""
    stack = [(curr_status, 0)]
    seen = set()
    while stack:
        curr, curr_count = stack.pop(0)
        if curr == goal_status:
            return curr_count
        for button in buttons:
            new_status = apply_button(curr.copy(), button)
            levels_valid = True
            # check if at least least one level is already too high
            for i in range(len(new_status)):
                if new_status[i] > goal_status[i]:
                    levels_valid = False
                    break
            if levels_valid and tuple(new_status) not in seen:
                seen.add(tuple(new_status))
                stack.append((new_status, curr_count+1))
    return -1

number_buttons_pressed = []
for idx, row in tqdm(input.iterrows(), total=len(input)):
    joltage_levels_goal = [int(level) for level in row["joltage_requirements"][1:-1].split(",")]
    joltage_levels = [0 for _ in range(len(joltage_levels_goal))]
    buttons = row["buttons"]
    number_buttons_pressed_row = bfs(joltage_levels, joltage_levels_goal, buttons)
    number_buttons_pressed.append(number_buttons_pressed_row)
print(f"The fewest button presses required are {sum(number_buttons_pressed)}")
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 56.14it/s]
# The fewest button presses required are 33

# %%
def parse_goal_vector(goal_str: str) -> List[int]:
    """Parses the goal string '{3,5,4,7}' into a list of integers [3, 5, 4, 7]."""
    return [
        int(level.strip()) 
        for level in goal_str.strip('{}').split(',')
    ]

def solve_machine(goal_g_str: str, buttons_def: List[str]) -> Union[int, float]:
    """
    Solves the problem as a pure Integer Linear Programming (ILP) problem using PuLP.
    """
    goal_g = parse_goal_vector(goal_g_str)
    N = len(goal_g)       # Number of counters
    M = len(buttons_def)  # Number of buttons

    prob = pulp.LpProblem("Minimize Button Presses", pulp.LpMinimize)
    
    # x_i
    press_vars = [
        pulp.LpVariable(f"x_{i}", lowBound=0, cat='Integer')
        for i in range(M)
    ]
    prob += pulp.lpSum(press_vars), "Total Presses"

    A = np.zeros((N, M), dtype=np.int8)
    for col_index, button_str in enumerate(buttons_def):
        indices_str = button_str.strip('()')
        if not indices_str: continue 
        counter_indices = [int(i.strip()) for i in indices_str.split(',')]
        for row_index in counter_indices:
            if 0 <= row_index < N:
                A[row_index, col_index] = 1

    # A * x = G
    for row_index in range(N):
        equation_terms = [
            A[row_index, col_index] * press_vars[col_index] 
            for col_index in range(M)
        ]
        prob += pulp.lpSum(equation_terms) == goal_g[row_index], f"Joltage_Eq_{row_index}"

    prob.solve()

    if prob.status == pulp.LpStatusOptimal:
        return int(pulp.value(prob.objective))
    return np.inf

number_buttons_pressed = []

for _, row in input.iterrows():
    min_presses = solve_machine(
        goal_g_str=row["joltage_requirements"],
        buttons_def=row["buttons"]
    )
    number_buttons_pressed.append(min_presses)

valid_presses = [p for p in number_buttons_pressed if p != np.inf]

print(f"The fewest button presses required are {sum(valid_presses)}")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/a084e38800a34b8193d67a519cc6eee8-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/a084e38800a34b8193d67a519cc6eee8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 39 RHS
# At line 46 BOUNDS
# At line 51 ENDATA
# Problem MODEL has 6 rows, 4 columns and 15 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 138 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 138 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                138.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/a0d74b4854ec43ba9cd230936ff357cb-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/a0d74b4854ec43ba9cd230936ff357cb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 24 RHS
# At line 29 BOUNDS
# At line 33 ENDATA
# Problem MODEL has 4 rows, 3 columns and 5 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 38 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 38 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                38.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/3d201c35a464496c89369968787a5dbd-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/3d201c35a464496c89369968787a5dbd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 43 RHS
# At line 50 BOUNDS
# At line 56 ENDATA
# Problem MODEL has 6 rows, 5 columns and 16 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 52 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 52 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                52.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/65ffd15ce9bc4b8f90a1f7930e93ce3d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/65ffd15ce9bc4b8f90a1f7930e93ce3d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 52 RHS
# At line 59 BOUNDS
# At line 67 ENDATA
# Problem MODEL has 6 rows, 7 columns and 19 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 64 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 64 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                64.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/d7be7b6c6145469fa0b721cb167ec922-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/d7be7b6c6145469fa0b721cb167ec922-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 50 RHS
# At line 57 BOUNDS
# At line 64 ENDATA
# Problem MODEL has 6 rows, 6 columns and 20 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 62 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 62 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                62.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/bed52fea51894100a396aad33cdf06d4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/bed52fea51894100a396aad33cdf06d4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 102 RHS
# At line 113 BOUNDS
# At line 124 ENDATA
# Problem MODEL has 10 rows, 10 columns and 56 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 107 - 0.00 seconds
# Cgl0004I processed model has 9 rows, 9 columns (9 integer (0 of which binary)) and 48 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0012I Integer solution of 107 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 107, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 107 to 107
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                107.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/c03024a5fa1f4ef1a8ded1eb32c9bf3b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/c03024a5fa1f4ef1a8ded1eb32c9bf3b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 60 RHS
# At line 69 BOUNDS
# At line 77 ENDATA
# Problem MODEL has 8 rows, 7 columns and 25 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 199 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 199 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                199.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/76830c8ab3c94ed489c905c5edd847d1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/76830c8ab3c94ed489c905c5edd847d1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 100 RHS
# At line 111 BOUNDS
# At line 124 ENDATA
# Problem MODEL has 10 rows, 12 columns and 48 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 128.5 - 0.00 seconds
# Cgl0004I processed model has 10 rows, 12 columns (12 integer (0 of which binary)) and 48 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Full problem 10 rows 12 columns, reduced to 10 rows 12 columns
# Cbc0012I Integer solution of 129 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 129, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 128.5 to 128.5
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                129.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/fec40111fb7f42c9b9278044b4f20d54-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/fec40111fb7f42c9b9278044b4f20d54-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 106 RHS
# At line 117 BOUNDS
# At line 128 ENDATA
# Problem MODEL has 10 rows, 10 columns and 60 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 78 - 0.00 seconds
# Cgl0004I processed model has 10 rows, 10 columns (10 integer (0 of which binary)) and 60 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0012I Integer solution of 78 found by greedy equality after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 78, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 78 to 78
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                78.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/b0ffb3f3e51a43b6b565933ea23dc55e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/b0ffb3f3e51a43b6b565933ea23dc55e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 31 RHS
# At line 36 BOUNDS
# At line 41 ENDATA
# Problem MODEL has 4 rows, 4 columns and 9 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 39 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 39 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                39.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/dbe81d1ab7854684881633ffd82c9475-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/dbe81d1ab7854684881633ffd82c9475-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 62 RHS
# At line 71 BOUNDS
# At line 79 ENDATA
# Problem MODEL has 8 rows, 7 columns and 27 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 237 - 0.00 seconds
# Cgl0003I 0 fixed, 2 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 237 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                237.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/b0ed52e63c0d4958805ce55380ff6113-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/b0ed52e63c0d4958805ce55380ff6113-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 56 RHS
# At line 65 BOUNDS
# At line 72 ENDATA
# Problem MODEL has 8 rows, 6 columns and 24 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 81 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 81 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                81.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/43b0fadc47244e278504cc0544dcd4a7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/43b0fadc47244e278504cc0544dcd4a7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 116 RHS
# At line 127 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 10 rows, 11 columns and 67 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 107 - 0.00 seconds
# Cgl0004I processed model has 10 rows, 11 columns (11 integer (0 of which binary)) and 67 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0012I Integer solution of 107 found by greedy equality after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 107, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 107 to 107
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                107.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/0764f82a969d42ecb104a60edb3c7d39-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/0764f82a969d42ecb104a60edb3c7d39-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 14 COLUMNS
# At line 79 RHS
# At line 89 BOUNDS
# At line 99 ENDATA
# Problem MODEL has 9 rows, 9 columns and 37 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 83 - 0.00 seconds
# Cgl0004I processed model has 7 rows, 7 columns (7 integer (0 of which binary)) and 29 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0012I Integer solution of 83 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 83, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 83 to 83
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                83.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/f988630c21fe44fc839ebfec280fbbbd-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/f988630c21fe44fc839ebfec280fbbbd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 113 RHS
# At line 124 BOUNDS
# At line 138 ENDATA
# Problem MODEL has 10 rows, 13 columns and 58 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 111 - 0.00 seconds
# Cgl0004I processed model has 10 rows, 13 columns (13 integer (0 of which binary)) and 58 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0012I Integer solution of 111 found by greedy equality after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 111, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 111 to 111
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                111.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/bf3fe9fe92424e8cabcba8ee1c95da6e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/bf3fe9fe92424e8cabcba8ee1c95da6e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 52 RHS
# At line 59 BOUNDS
# At line 66 ENDATA
# Problem MODEL has 6 rows, 6 columns and 22 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 219 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 219 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                219.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/0620c7a7c97e4fedb75ca0a98887d57c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/0620c7a7c97e4fedb75ca0a98887d57c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 14 COLUMNS
# At line 75 RHS
# At line 85 BOUNDS
# At line 93 ENDATA
# Problem MODEL has 9 rows, 7 columns and 39 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 81 - 0.00 seconds
# Cgl0004I processed model has 9 rows, 7 columns (7 integer (0 of which binary)) and 39 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0012I Integer solution of 81 found by greedy equality after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 81, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 81 to 81
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                81.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/c15312b81dc54d4294bb27ad1b828101-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/c15312b81dc54d4294bb27ad1b828101-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 72 RHS
# At line 81 BOUNDS
# At line 91 ENDATA
# Problem MODEL has 8 rows, 9 columns and 31 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 74 - 0.00 seconds
# Cgl0004I processed model has 6 rows, 7 columns (7 integer (0 of which binary)) and 26 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0012I Integer solution of 74 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 74, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 74 to 74
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                74.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/ce026dd40bfe4761863d67444a4fcb01-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/ce026dd40bfe4761863d67444a4fcb01-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 12 COLUMNS
# At line 71 RHS
# At line 79 BOUNDS
# At line 89 ENDATA
# Problem MODEL has 7 rows, 9 columns and 31 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 93 - 0.00 seconds
# Cgl0004I processed model has 7 rows, 9 columns (9 integer (0 of which binary)) and 31 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0012I Integer solution of 93 found by greedy equality after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 93, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 93 to 93
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                93.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/390315c512ac4f57b73a958483ce8602-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/390315c512ac4f57b73a958483ce8602-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 39 RHS
# At line 44 BOUNDS
# At line 51 ENDATA
# Problem MODEL has 4 rows, 6 columns and 11 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 60 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 60 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                60.00000000
# Enumerated nodes:               0
# ...
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/fe31a15d467748258b7a223d1d280153-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/fe31a15d467748258b7a223d1d280153-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 39 RHS
# At line 44 BOUNDS
# At line 51 ENDATA
# Problem MODEL has 4 rows, 6 columns and 11 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 55 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 55 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                55.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/d79027d3432144c086851963258d9020-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/d79027d3432144c086851963258d9020-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 75 RHS
# At line 84 BOUNDS
# At line 94 ENDATA
# Problem MODEL has 8 rows, 9 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 103 - 0.00 seconds
# Cgl0004I processed model has 7 rows, 8 columns (8 integer (0 of which binary)) and 28 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0012I Integer solution of 103 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 103, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 103 to 103
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                103.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/1c6a24480f1e4156af56a729dd0d68f1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/1c6a24480f1e4156af56a729dd0d68f1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 46 RHS
# At line 52 BOUNDS
# At line 59 ENDATA
# Problem MODEL has 5 rows, 6 columns and 17 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 221.667 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 5 columns (5 integer (0 of which binary)) and 13 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0012I Integer solution of 222 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 222, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 221.667 to 221.667
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                222.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/8140e569ba2d45049138f0809634c217-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/8140e569ba2d45049138f0809634c217-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 86 RHS
# At line 97 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 10 rows, 10 columns and 40 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 93 - 0.00 seconds
# Cgl0004I processed model has 9 rows, 9 columns (9 integer (0 of which binary)) and 38 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0012I Integer solution of 93 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 93, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 93 to 93
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                93.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/18a14bd9e80f477489e4614cafb6f198-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/18a14bd9e80f477489e4614cafb6f198-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 86 RHS
# At line 95 BOUNDS
# At line 106 ENDATA
# Problem MODEL has 8 rows, 10 columns and 42 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 93 - 0.00 seconds
# Cgl0004I processed model has 7 rows, 9 columns (9 integer (0 of which binary)) and 38 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0012I Integer solution of 94 found by DiveCoefficient after 1 iterations and 0 nodes (0.00 seconds)
# Cbc0031I 1 added rows had average density of 2
# Cbc0013I At root node, 1 cuts changed objective from 93 to 94 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 2 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 5 row cuts average 2.2 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0001I Search completed - best objective 94, took 1 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 93 to 94
# Probing was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 2 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 2 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                94.00000000
# Enumerated nodes:               0
# Total iterations:               1
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/floriandreyer/Library/Mobile Documents/com~apple~CloudDocs/Programmierprojekte/AdventOfCode_2025/.venv/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/434642d8c08e41928ada6a0b49cf14dd-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/kj/q_05bvdx3s9crpx2lctmxkdr0000gn/T/434642d8c08e41928ada6a0b49cf14dd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 40 RHS
# At line 45 BOUNDS
# At line 52 ENDATA
# Problem MODEL has 4 rows, 6 columns and 12 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 72 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 72 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                72.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# The fewest button presses required are 20617
